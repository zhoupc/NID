# %%
from NID.datasets import Pinky40
from NID.models import DnCNN
from NID.utils import weights_init_kaiming, batch_PSNR

import numpy as np
import scipy.io as sio 
import matplotlib.pyplot as plt 
from mpl_toolkits.axes_grid1 import make_axes_locatable
from dataclasses import dataclass

import os
import h5py
import random
import cv2
import torch 
import torch.nn as nn 
import torch.optim as optim
import torchvision.utils as utils
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from tensorboardX import SummaryWriter 

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

@dataclass
class training_configurations: 
    '''class for storing options of the netowrk training'''
    preprocess: bool = False  
    batchSize: int = 256    # training batch size 
    num_of_layers: int = 3 # number of total layers 
    epochs: int = 3   #number of training epochs 
    milestone: int = 1 # when to decay learning rate 
    lr: float = 1e-3  # initial learning rate 
    outf: str = 'logs' #path of log files 
    mode: str = 'M' #with known noise level (S) or blind training (B)
    noiseL: float = 0.1 # noise level
    val_noiseL: float = 0.2 # nosie level used on validation set

# %%
import cv2
kernel = np.ones((2, 2), np.uint8) 

img = torch.rand((60, 80))>0.99
img_dilation = cv2.dilate(img.numpy(), kernel) 
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img_dilation)

# %% [markdown]
# # prepare data

# %%
dataset_train = Pinky40(train=True, patch=29)
print(type(dataset_train))
dataset_val = Pinky40(train=False)
loader_train = DataLoader(dataset=dataset_train, num_workers=4, 
                         batch_size=256, shuffle=True)
print("# of training samples: %d\n" % len(dataset_train))
print("# of testing samples: %d\n" % len(dataset_val))
# Out:
# <class 'NID.datasets.Pinky40'>
# # of training samples: 194581
#
# # of testing samples: 311

# %% [markdown]
# # configure training options

# %%
opt = training_configurations()
opt
# Out:
# training_configurations(preprocess=False, batchSize=256, num_of_layers=3, epochs=3, milestone=1, lr=0.001, outf='logs', mode='M', noiseL=0.1, val_noiseL=0.2)

# %% [markdown]
# # build model

# %%
net = DnCNN(channels=1, num_of_layers=opt.num_of_layers)
# Move to GPU
device_ids = [0]
#initialize weights
file_results = os.path.join(opt.outf, 'net_{}_state0.pth'.format(opt.num_of_layers))

if os.path.exists(file_results):
    print('use the trained model as the initialization')
    model = nn.DataParallel(net, device_ids=device_ids).cuda()
    model.load_state_dict(torch.load(file_results))
    model.eval()
else:
    print("start from scratch to initialize the model")
    net.apply(weights_init_kaiming)
    if len(device_ids)==1: 
        device = torch.device('cuda:0')
        model = net.to(device)
    else: 
        model = nn.DataParallel(net, device_ids=device_ids).cuda()
    
criterion = nn.MSELoss(reduction='sum')
criterion.cuda()
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=opt.lr)
# training
writer = SummaryWriter(opt.outf)
step = 0
# opt.lr = 1e-4
# Out:
# start from scratch to initialize the model

# %% [markdown]
# # start training - GPU

# %%
output_file = os.path.join(opt.outf, 'net_{}_connector.pth'.format(opt.num_of_layers))
train_again = True 

if os.path.exists(output_file) and (not train_again): 
    # load the saved model directly 
    model.load_state_dict(torch.load(output_file))
else: 
    # train the model again 
    for epoch in range(opt.epochs):
        # reduce the learning rate after opt.milestone iterations
        if epoch < opt.milestone:
            current_lr = opt.lr
        else:
            current_lr = opt.lr / 10.

        # set learning rate
        for param_group in optimizer.param_groups:
            param_group["lr"] = current_lr
        print('epoch %d: learning rate %f' % (epoch, current_lr))
        
        # train
        for i, data in enumerate(loader_train, 0):
            # training step
            model.train()
            model.zero_grad()
            optimizer.zero_grad()
            img_train = data
            
            # generate noisy images 
            if opt.mode == 'S':
                noise = torch.FloatTensor(img_train.size()).normal_(mean=0, std=opt.noiseL)
            elif opt.mode == 'B':
                noise = torch.zeros(img_train.size())
                stdN = np.random.uniform(noiseL_B[0], noiseL_B[1], size=noise.size()[0])
                for n in range(noise.size()[0]):
                    sizeN = noise[0,:,:,:].size()
                    noise[n,:,:,:] = torch.FloatTensor(sizeN).normal_(mean=0, std=stdN[n])
            elif opt.mode == 'M':
                img_train[img_train>0] = 1 
                noise = torch.zeros(img_train.size())
                noise[torch.rand(img_train.size()) > 0.9] = -1
                
            imgn_train = img_train + noise
            img_train, imgn_train = Variable(img_train.cuda()), Variable(imgn_train.cuda())
            noise = Variable(noise.cuda())
            
            # define the model output
            out_train = model(imgn_train)
            
            # define the objective function 
            loss = criterion(out_train, noise) / (imgn_train.size()[0]*2)
            
            # update model parameters using back-propagation 
            loss.backward()
            optimizer.step()
            
            # results
            model.eval()
            out_train = torch.clamp(imgn_train-model(imgn_train), 0., 1.)
            psnr_train = batch_PSNR(out_train, img_train, 1.)
            print("[epoch %d][%d/%d] loss: %.4f PSNR_train: %.4f" %
                (epoch+1, i+1, len(loader_train), loss.item(), psnr_train))
            # if you are using older version of PyTorch, you may need to change loss.item() to loss.data[0]
            
            if step % 100 == 0:
                # Log the scalar values
                writer.add_scalar('loss', loss.item(), step)
                writer.add_scalar('PSNR on training data', psnr_train, step)
            step += 1
            
        # evaluate the model using the test data 
        model.eval()

        psnr_val = 0
        for k in range(len(dataset_val)):
            img_val = torch.unsqueeze(dataset_val[k], 0)
            # generate noise 
            if opt.mode == 'S':
                noise = torch.FloatTensor(img_val.size()).normal_(mean=0, std=opt.noiseL)
            elif opt.mode == 'B':
                noise = torch.zeros(img_val.size())
                stdN = np.random.uniform(noiseL_B[0], noiseL_B[1], size=noise.size()[0])
                for n in range(noise.size()[0]):
                    sizeN = noise[0,:,:,:].size()
                    noise[n,:,:,:] = torch.FloatTensor(sizeN).normal_(mean=0, std=stdN[n])
            elif opt.mode == 'M': 
                img_val[img_val>0] = 1 
                noise = torch.zeros(img_train.size())
                noise[torch.rand(img_train.size()) > 0.9] = -1
            
            imgn_val = img_val + noise
            img_val, imgn_val = Variable(img_val.cuda()), Variable(imgn_val.cuda())
            out_val = torch.clamp(imgn_val-model(imgn_val), 0., 1.)
            psnr_val += batch_PSNR(out_val, img_val, 1.)
            
        psnr_val /= len(dataset_val)
        print("\n[epoch %d] PSNR_val: %.4f" % (epoch+1, psnr_val))
        writer.add_scalar('PSNR on validation data', psnr_val, epoch)

        # save model
        torch.save(model.state_dict(), os.path.join(opt.outf, 'net_{}_connector.pth'.format(opt.num_of_layers)))
# Out:
# epoch 0: learning rate 0.001000
# [epoch 1][1/761] loss: 21.5887 PSNR_train: 21.2509
# [epoch 1][2/761] loss: 11.3897 PSNR_train: 19.1958
# [epoch 1][3/761] loss: 6.3567 PSNR_train: 17.1669
# [epoch 1][4/761] loss: 5.3880 PSNR_train: 17.3847
# [epoch 1][5/761] loss: 5.5726 PSNR_train: 19.9541
# [epoch 1][6/761] loss: 6.3954 PSNR_train: 22.0303
# [epoch 1][7/761] loss: 7.1356 PSNR_train: 22.9812
# [epoch 1][8/761] loss: 8.3017 PSNR_train: 23.0570
# [epoch 1][9/761] loss: 8.4470 PSNR_train: 23.0686
# [epoch 1][10/761] loss: 7.6059 PSNR_train: 23.1295
# [epoch 1][11/761] loss: 5.2907 PSNR_train: 24.0343
# [epoch 1][12/761] loss: 4.4355 PSNR_train: 22.9765
# [epoch 1][13/761] loss: 3.5766 PSNR_train: 22.9778
# [epoch 1][14/761] loss: 3.1423 PSNR_train: 22.6290
# [epoch 1][15/761] loss: 3.2595 PSNR_train: 22.0300
# [epoch 1][16/761] loss: 3.2685 PSNR_train: 21.7598
# [epoch 1][17/761] loss: 3.6770 PSNR_train: 21.1969
# [epoch 1][18/761] loss: 3.6810 PSNR_train: 21.1716
# [epoch 1][19/761] loss: 3.6794 PSNR_train: 21.2233
# [epoch 1][20/761] loss: 3.6311 PSNR_train: 21.5126
# [epoch 1][21/761] loss: 3.3288 PSNR_train: 22.2348
# [epoch 1][22/761] loss: 3.1443 PSNR_train: 22.6846
# [epoch 1][23/761] loss: 3.0986 PSNR_train: 22.9064
# [epoch 1][24/761] loss: 2.8831 PSNR_train: 23.2840
# [epoch 1][25/761] loss: 2.7359 PSNR_train: 23.9237
# [epoch 1][26/761] loss: 2.9821 PSNR_train: 23.7018
# [epoch 1][27/761] loss: 2.9751 PSNR_train: 23.6717
# [epoch 1][28/761] loss: 3.0059 PSNR_train: 23.7428
# [epoch 1][29/761] loss: 2.8609 PSNR_train: 23.9113
# [epoch 1][30/761] loss: 2.6879 PSNR_train: 24.2903
# [epoch 1][31/761] loss: 3.0758 PSNR_train: 23.6059
# [epoch 1][32/761] loss: 2.7057 PSNR_train: 24.0948
# [epoch 1][33/761] loss: 2.6388 PSNR_train: 23.7177
# [epoch 1][34/761] loss: 2.5907 PSNR_train: 24.0324
# [epoch 1][35/761] loss: 2.5479 PSNR_train: 23.8384
# [epoch 1][36/761] loss: 2.6433 PSNR_train: 23.7584
# [epoch 1][37/761] loss: 2.6445 PSNR_train: 23.5219
# [epoch 1][38/761] loss: 2.5946 PSNR_train: 23.6134
# [epoch 1][39/761] loss: 2.7559 PSNR_train: 23.1999
# [epoch 1][40/761] loss: 2.5113 PSNR_train: 23.8317
# [epoch 1][41/761] loss: 2.5950 PSNR_train: 23.6157
# [epoch 1][42/761] loss: 2.7158 PSNR_train: 23.5481
# [epoch 1][43/761] loss: 2.4499 PSNR_train: 23.9369
# [epoch 1][44/761] loss: 2.8203 PSNR_train: 23.6031
# [epoch 1][45/761] loss: 2.4370 PSNR_train: 24.0502
# [epoch 1][46/761] loss: 2.5737 PSNR_train: 23.9583
# [epoch 1][47/761] loss: 2.4310 PSNR_train: 24.4813
# [epoch 1][48/761] loss: 2.4141 PSNR_train: 24.2332
# [epoch 1][49/761] loss: 2.6219 PSNR_train: 24.0359
# [epoch 1][50/761] loss: 2.7197 PSNR_train: 23.9500
# [epoch 1][51/761] loss: 2.4684 PSNR_train: 24.0698
# [epoch 1][52/761] loss: 2.3705 PSNR_train: 24.6919
# [epoch 1][53/761] loss: 2.4744 PSNR_train: 24.3237
# [epoch 1][54/761] loss: 2.8025 PSNR_train: 23.5041
# [epoch 1][55/761] loss: 2.4234 PSNR_train: 24.1189
# [epoch 1][56/761] loss: 2.4211 PSNR_train: 24.1671
# [epoch 1][57/761] loss: 2.4297 PSNR_train: 24.3458
# [epoch 1][58/761] loss: 2.5261 PSNR_train: 24.1464
# [epoch 1][59/761] loss: 2.4988 PSNR_train: 23.9783
# [epoch 1][60/761] loss: 2.3210 PSNR_train: 24.5055
# [epoch 1][61/761] loss: 2.5801 PSNR_train: 23.7550
# [epoch 1][62/761] loss: 2.3209 PSNR_train: 24.5475
# [epoch 1][63/761] loss: 2.4931 PSNR_train: 23.9777
# [epoch 1][64/761] loss: 2.2228 PSNR_train: 24.6791
# [epoch 1][65/761] loss: 2.6154 PSNR_train: 23.8095
# [epoch 1][66/761] loss: 2.5300 PSNR_train: 23.9276
# [epoch 1][67/761] loss: 2.3807 PSNR_train: 23.9420
# [epoch 1][68/761] loss: 2.3249 PSNR_train: 24.4438
# [epoch 1][69/761] loss: 2.4434 PSNR_train: 24.1528
# [epoch 1][70/761] loss: 2.3256 PSNR_train: 24.2415
# [epoch 1][71/761] loss: 2.4108 PSNR_train: 24.0868
# [epoch 1][72/761] loss: 2.3997 PSNR_train: 24.2471
# [epoch 1][73/761] loss: 2.1805 PSNR_train: 24.6700
# [epoch 1][74/761] loss: 2.2297 PSNR_train: 24.5011
# [epoch 1][75/761] loss: 2.2926 PSNR_train: 24.4116
# [epoch 1][76/761] loss: 2.6615 PSNR_train: 23.7478
# [epoch 1][77/761] loss: 2.4687 PSNR_train: 24.1648
# [epoch 1][78/761] loss: 2.3787 PSNR_train: 24.4306
# [epoch 1][79/761] loss: 2.3212 PSNR_train: 24.1916
# [epoch 1][80/761] loss: 2.4883 PSNR_train: 24.0924
# [epoch 1][81/761] loss: 2.3952 PSNR_train: 24.0690
# [epoch 1][82/761] loss: 2.2370 PSNR_train: 24.5952
# [epoch 1][83/761] loss: 2.3002 PSNR_train: 24.2848
# [epoch 1][84/761] loss: 2.3726 PSNR_train: 24.2455
# [epoch 1][85/761] loss: 2.2931 PSNR_train: 24.4635
# [epoch 1][86/761] loss: 2.4000 PSNR_train: 23.9474
# [epoch 1][87/761] loss: 2.1609 PSNR_train: 25.0352
# [epoch 1][88/761] loss: 2.2178 PSNR_train: 24.5164
# [epoch 1][89/761] loss: 2.2680 PSNR_train: 24.4996
# [epoch 1][90/761] loss: 2.2693 PSNR_train: 24.5237
# [epoch 1][91/761] loss: 2.2984 PSNR_train: 24.0763
# [epoch 1][92/761] loss: 2.1917 PSNR_train: 24.7067
# [epoch 1][93/761] loss: 2.4794 PSNR_train: 23.9314
# [epoch 1][94/761] loss: 2.1334 PSNR_train: 24.7042
# [epoch 1][95/761] loss: 2.3391 PSNR_train: 24.3238
# [epoch 1][96/761] loss: 2.4128 PSNR_train: 24.1876
# [epoch 1][97/761] loss: 2.0719 PSNR_train: 24.8081
# [epoch 1][98/761] loss: 2.4078 PSNR_train: 24.1618
# [epoch 1][99/761] loss: 2.4180 PSNR_train: 24.1757
# [epoch 1][100/761] loss: 2.2862 PSNR_train: 24.4485
# [epoch 1][101/761] loss: 2.4426 PSNR_train: 23.9466
# [epoch 1][102/761] loss: 2.3512 PSNR_train: 24.4304
# [epoch 1][103/761] loss: 2.3955 PSNR_train: 24.2139
# [epoch 1][104/761] loss: 2.2424 PSNR_train: 24.3114
# [epoch 1][105/761] loss: 2.1836 PSNR_train: 24.5376
# [epoch 1][106/761] loss: 2.2693 PSNR_train: 24.5818
# [epoch 1][107/761] loss: 2.2725 PSNR_train: 24.3624
# [epoch 1][108/761] loss: 2.2024 PSNR_train: 24.8261
# [epoch 1][109/761] loss: 2.2737 PSNR_train: 24.4326
# [epoch 1][110/761] loss: 2.4144 PSNR_train: 24.2386
# [epoch 1][111/761] loss: 2.3385 PSNR_train: 24.2328
# [epoch 1][112/761] loss: 2.2154 PSNR_train: 24.5837
# [epoch 1][113/761] loss: 2.4194 PSNR_train: 23.9726
# [epoch 1][114/761] loss: 2.2790 PSNR_train: 24.4479
# [epoch 1][115/761] loss: 2.5125 PSNR_train: 23.7169
# [epoch 1][116/761] loss: 2.1850 PSNR_train: 24.6008
# [epoch 1][117/761] loss: 2.2419 PSNR_train: 24.4570
# [epoch 1][118/761] loss: 2.1626 PSNR_train: 24.5561
# [epoch 1][119/761] loss: 2.2053 PSNR_train: 24.5280
# [epoch 1][120/761] loss: 2.1905 PSNR_train: 24.4666
# [epoch 1][121/761] loss: 2.1878 PSNR_train: 24.6037
# [epoch 1][122/761] loss: 2.0433 PSNR_train: 24.7352
# [epoch 1][123/761] loss: 2.1812 PSNR_train: 24.6182
# [epoch 1][124/761] loss: 2.1525 PSNR_train: 24.6364
# [epoch 1][125/761] loss: 2.1528 PSNR_train: 24.7798
# [epoch 1][126/761] loss: 2.1199 PSNR_train: 24.8570
# [epoch 1][127/761] loss: 2.1207 PSNR_train: 24.9336
# [epoch 1][128/761] loss: 2.1419 PSNR_train: 24.5601
# [epoch 1][129/761] loss: 2.3381 PSNR_train: 24.3483
# [epoch 1][130/761] loss: 2.3789 PSNR_train: 24.3480
# [epoch 1][131/761] loss: 2.0779 PSNR_train: 24.7626
# [epoch 1][132/761] loss: 2.1268 PSNR_train: 24.8417
# [epoch 1][133/761] loss: 2.4954 PSNR_train: 23.8920
# [epoch 1][134/761] loss: 2.1214 PSNR_train: 24.5407
# [epoch 1][135/761] loss: 2.1953 PSNR_train: 24.6769
# [epoch 1][136/761] loss: 2.3294 PSNR_train: 24.4530
# [epoch 1][137/761] loss: 2.0699 PSNR_train: 24.9935
# [epoch 1][138/761] loss: 2.1956 PSNR_train: 24.6771
# [epoch 1][139/761] loss: 2.1852 PSNR_train: 24.5953
# [epoch 1][140/761] loss: 1.8496 PSNR_train: 25.3196
# [epoch 1][141/761] loss: 2.1573 PSNR_train: 24.6576
# [epoch 1][142/761] loss: 2.1922 PSNR_train: 24.4772
# [epoch 1][143/761] loss: 2.2108 PSNR_train: 24.5777
# [epoch 1][144/761] loss: 2.1414 PSNR_train: 24.7725
# [epoch 1][145/761] loss: 2.2109 PSNR_train: 24.3542
# [epoch 1][146/761] loss: 2.3222 PSNR_train: 24.4368
# [epoch 1][147/761] loss: 2.2824 PSNR_train: 24.4658
# [epoch 1][148/761] loss: 2.1609 PSNR_train: 24.9209
# [epoch 1][149/761] loss: 2.3574 PSNR_train: 24.4593
# [epoch 1][150/761] loss: 2.2734 PSNR_train: 24.5259
# [epoch 1][151/761] loss: 2.1727 PSNR_train: 24.4973
# [epoch 1][152/761] loss: 2.1939 PSNR_train: 24.6561
# [epoch 1][153/761] loss: 2.0195 PSNR_train: 24.8032
# [epoch 1][154/761] loss: 2.2073 PSNR_train: 24.8191
# [epoch 1][155/761] loss: 2.1111 PSNR_train: 24.8791
# [epoch 1][156/761] loss: 2.0882 PSNR_train: 25.0604
# [epoch 1][157/761] loss: 2.2270 PSNR_train: 24.7274
# [epoch 1][158/761] loss: 2.2265 PSNR_train: 24.4782
# [epoch 1][159/761] loss: 2.2317 PSNR_train: 24.6899
# [epoch 1][160/761] loss: 2.1543 PSNR_train: 24.8108
# [epoch 1][161/761] loss: 2.1568 PSNR_train: 24.8740
# [epoch 1][162/761] loss: 2.1011 PSNR_train: 25.0173
# [epoch 1][163/761] loss: 2.0581 PSNR_train: 24.9107
# [epoch 1][164/761] loss: 2.3901 PSNR_train: 24.2763
# [epoch 1][165/761] loss: 2.2503 PSNR_train: 24.3619
# [epoch 1][166/761] loss: 2.0720 PSNR_train: 24.9031
# [epoch 1][167/761] loss: 2.1723 PSNR_train: 24.8007
# [epoch 1][168/761] loss: 1.9162 PSNR_train: 25.0672
# [epoch 1][169/761] loss: 2.1168 PSNR_train: 24.6715
# [epoch 1][170/761] loss: 2.1596 PSNR_train: 25.0713
# [epoch 1][171/761] loss: 2.0225 PSNR_train: 25.0538
# [epoch 1][172/761] loss: 1.9707 PSNR_train: 24.9938
# [epoch 1][173/761] loss: 2.1917 PSNR_train: 24.8348
# [epoch 1][174/761] loss: 2.2136 PSNR_train: 24.5999
# [epoch 1][175/761] loss: 1.9225 PSNR_train: 25.0908
# [epoch 1][176/761] loss: 1.9301 PSNR_train: 25.0747
# [epoch 1][177/761] loss: 1.9822 PSNR_train: 25.2493
# [epoch 1][178/761] loss: 2.1529 PSNR_train: 24.6763
# [epoch 1][179/761] loss: 2.1249 PSNR_train: 24.8355
# [epoch 1][180/761] loss: 2.1177 PSNR_train: 24.6248
# [epoch 1][181/761] loss: 2.1870 PSNR_train: 24.6238
# [epoch 1][182/761] loss: 2.2225 PSNR_train: 24.6064
# [epoch 1][183/761] loss: 2.1452 PSNR_train: 24.5147
# [epoch 1][184/761] loss: 2.1660 PSNR_train: 24.5366
# [epoch 1][185/761] loss: 2.1484 PSNR_train: 24.7754
# [epoch 1][186/761] loss: 1.9365 PSNR_train: 25.1090
# [epoch 1][187/761] loss: 2.1540 PSNR_train: 25.0872
# [epoch 1][188/761] loss: 2.1406 PSNR_train: 24.5978
# [epoch 1][189/761] loss: 2.1360 PSNR_train: 24.9642
# [epoch 1][190/761] loss: 2.1640 PSNR_train: 24.9684
# [epoch 1][191/761] loss: 2.2159 PSNR_train: 24.5226
# [epoch 1][192/761] loss: 2.0384 PSNR_train: 24.7855
# [epoch 1][193/761] loss: 2.0355 PSNR_train: 25.0558
# [epoch 1][194/761] loss: 2.3773 PSNR_train: 24.7451
# [epoch 1][195/761] loss: 2.1148 PSNR_train: 24.8002
# [epoch 1][196/761] loss: 1.9260 PSNR_train: 25.3874
# [epoch 1][197/761] loss: 2.2099 PSNR_train: 24.8502
# [epoch 1][198/761] loss: 2.2104 PSNR_train: 24.5879
# [epoch 1][199/761] loss: 1.9258 PSNR_train: 25.2207
# [epoch 1][200/761] loss: 2.0396 PSNR_train: 24.8697
# [epoch 1][201/761] loss: 2.1210 PSNR_train: 24.9024
# [epoch 1][202/761] loss: 2.2406 PSNR_train: 24.6007
# [epoch 1][203/761] loss: 2.0577 PSNR_train: 24.8481
# [epoch 1][204/761] loss: 2.3716 PSNR_train: 24.4495
# [epoch 1][205/761] loss: 2.1626 PSNR_train: 24.7018
# [epoch 1][206/761] loss: 2.1551 PSNR_train: 24.5521
# [epoch 1][207/761] loss: 2.0188 PSNR_train: 24.9573
# [epoch 1][208/761] loss: 2.0321 PSNR_train: 25.0507
# [epoch 1][209/761] loss: 2.1723 PSNR_train: 24.5039
# [epoch 1][210/761] loss: 2.1785 PSNR_train: 24.8542
# [epoch 1][211/761] loss: 2.1620 PSNR_train: 24.9031
# [epoch 1][212/761] loss: 2.1572 PSNR_train: 24.7732
# [epoch 1][213/761] loss: 2.1773 PSNR_train: 24.8051
# [epoch 1][214/761] loss: 2.1641 PSNR_train: 24.8042
# [epoch 1][215/761] loss: 2.2386 PSNR_train: 24.6870
# [epoch 1][216/761] loss: 2.1470 PSNR_train: 24.9129
# [epoch 1][217/761] loss: 2.0597 PSNR_train: 24.6996
# [epoch 1][218/761] loss: 2.0369 PSNR_train: 24.8425
# [epoch 1][219/761] loss: 2.0891 PSNR_train: 24.6986
# [epoch 1][220/761] loss: 2.1787 PSNR_train: 24.9494
# [epoch 1][221/761] loss: 2.1357 PSNR_train: 24.9300
# [epoch 1][222/761] loss: 2.1758 PSNR_train: 24.9521
# [epoch 1][223/761] loss: 2.1173 PSNR_train: 24.8102
# [epoch 1][224/761] loss: 2.1236 PSNR_train: 24.8257
# [epoch 1][225/761] loss: 2.1287 PSNR_train: 24.8072
# [epoch 1][226/761] loss: 2.1808 PSNR_train: 24.8068
# [epoch 1][227/761] loss: 2.3588 PSNR_train: 24.4053
# [epoch 1][228/761] loss: 2.2793 PSNR_train: 24.3746
# [epoch 1][229/761] loss: 2.0640 PSNR_train: 24.8956
# [epoch 1][230/761] loss: 2.0190 PSNR_train: 25.1756
# [epoch 1][231/761] loss: 2.4285 PSNR_train: 24.2793
# [epoch 1][232/761] loss: 2.1088 PSNR_train: 24.7345
# [epoch 1][233/761] loss: 2.2614 PSNR_train: 24.5538
# [epoch 1][234/761] loss: 1.9622 PSNR_train: 25.1211
# [epoch 1][235/761] loss: 2.1222 PSNR_train: 24.9285
# [epoch 1][236/761] loss: 2.0814 PSNR_train: 25.0351
# [epoch 1][237/761] loss: 2.1712 PSNR_train: 24.7099
# [epoch 1][238/761] loss: 2.2002 PSNR_train: 24.8128
# [epoch 1][239/761] loss: 2.0088 PSNR_train: 25.1969
# [epoch 1][240/761] loss: 2.0459 PSNR_train: 24.9289
# [epoch 1][241/761] loss: 2.1173 PSNR_train: 24.7427
# [epoch 1][242/761] loss: 2.1025 PSNR_train: 24.6125
# [epoch 1][243/761] loss: 2.1300 PSNR_train: 24.5796
# [epoch 1][244/761] loss: 2.1036 PSNR_train: 24.9422
# [epoch 1][245/761] loss: 2.0128 PSNR_train: 24.9536
# [epoch 1][246/761] loss: 2.2060 PSNR_train: 24.6254
# [epoch 1][247/761] loss: 2.0908 PSNR_train: 24.7238
# [epoch 1][248/761] loss: 2.0159 PSNR_train: 25.0800
# [epoch 1][249/761] loss: 2.1623 PSNR_train: 24.8445
# [epoch 1][250/761] loss: 2.1557 PSNR_train: 24.7347
# [epoch 1][251/761] loss: 2.2940 PSNR_train: 24.5537
# [epoch 1][252/761] loss: 2.0145 PSNR_train: 24.9965
# [epoch 1][253/761] loss: 2.3434 PSNR_train: 24.2804
# [epoch 1][254/761] loss: 2.0315 PSNR_train: 24.8554
# [epoch 1][255/761] loss: 1.9330 PSNR_train: 25.0576
# [epoch 1][256/761] loss: 2.2037 PSNR_train: 24.5119
# [epoch 1][257/761] loss: 2.1497 PSNR_train: 24.8186
# [epoch 1][258/761] loss: 1.9501 PSNR_train: 25.2944
# [epoch 1][259/761] loss: 2.2205 PSNR_train: 24.4319
# [epoch 1][260/761] loss: 2.1710 PSNR_train: 24.6927
# [epoch 1][261/761] loss: 2.3632 PSNR_train: 24.3341
# [epoch 1][262/761] loss: 2.1480 PSNR_train: 24.8104
# [epoch 1][263/761] loss: 1.8841 PSNR_train: 25.1636
# [epoch 1][264/761] loss: 2.1528 PSNR_train: 24.5353
# [epoch 1][265/761] loss: 2.0297 PSNR_train: 25.2343
# [epoch 1][266/761] loss: 1.9450 PSNR_train: 25.4829
# [epoch 1][267/761] loss: 1.9517 PSNR_train: 25.1526
# [epoch 1][268/761] loss: 2.1390 PSNR_train: 24.6102
# [epoch 1][269/761] loss: 1.9705 PSNR_train: 25.4693
# [epoch 1][270/761] loss: 2.1358 PSNR_train: 24.5909
# [epoch 1][271/761] loss: 2.0551 PSNR_train: 25.1245
# [epoch 1][272/761] loss: 2.3268 PSNR_train: 24.3296
# [epoch 1][273/761] loss: 2.0426 PSNR_train: 24.9774
# [epoch 1][274/761] loss: 2.0826 PSNR_train: 25.0092
# [epoch 1][275/761] loss: 2.1624 PSNR_train: 24.7934
# [epoch 1][276/761] loss: 2.0356 PSNR_train: 24.7315
# [epoch 1][277/761] loss: 1.9878 PSNR_train: 24.7133
# [epoch 1][278/761] loss: 2.1630 PSNR_train: 24.7559
# [epoch 1][279/761] loss: 2.2340 PSNR_train: 24.5308
# [epoch 1][280/761] loss: 2.1471 PSNR_train: 24.9229
# [epoch 1][281/761] loss: 2.0859 PSNR_train: 25.0697
# [epoch 1][282/761] loss: 1.9166 PSNR_train: 25.4787
# [epoch 1][283/761] loss: 2.1285 PSNR_train: 24.8556
# [epoch 1][284/761] loss: 2.2458 PSNR_train: 24.6929
# [epoch 1][285/761] loss: 2.0742 PSNR_train: 25.1323
# [epoch 1][286/761] loss: 2.1535 PSNR_train: 24.6373
# [epoch 1][287/761] loss: 2.0818 PSNR_train: 24.6393
# [epoch 1][288/761] loss: 2.1652 PSNR_train: 24.6175
# [epoch 1][289/761] loss: 2.1692 PSNR_train: 24.6427
# [epoch 1][290/761] loss: 2.0449 PSNR_train: 25.0990
# [epoch 1][291/761] loss: 2.0340 PSNR_train: 25.1940
# [epoch 1][292/761] loss: 2.0359 PSNR_train: 25.2207
# [epoch 1][293/761] loss: 1.9359 PSNR_train: 25.4591
# [epoch 1][294/761] loss: 1.8572 PSNR_train: 25.4938
# [epoch 1][295/761] loss: 1.9504 PSNR_train: 25.3718
# [epoch 1][296/761] loss: 2.1942 PSNR_train: 24.7488
# [epoch 1][297/761] loss: 2.2417 PSNR_train: 24.1857
# [epoch 1][298/761] loss: 1.8251 PSNR_train: 25.2744
# [epoch 1][299/761] loss: 2.3756 PSNR_train: 24.3008
# [epoch 1][300/761] loss: 1.9852 PSNR_train: 25.0507
# [epoch 1][301/761] loss: 1.9742 PSNR_train: 25.0684
# [epoch 1][302/761] loss: 2.0991 PSNR_train: 24.9080
# [epoch 1][303/761] loss: 2.1328 PSNR_train: 25.0060
# [epoch 1][304/761] loss: 2.1221 PSNR_train: 24.8360
# [epoch 1][305/761] loss: 1.9772 PSNR_train: 25.2098
# [epoch 1][306/761] loss: 2.1211 PSNR_train: 24.8951
# [epoch 1][307/761] loss: 1.9802 PSNR_train: 25.4512
# [epoch 1][308/761] loss: 2.0764 PSNR_train: 24.8494
# [epoch 1][309/761] loss: 2.1777 PSNR_train: 24.5193
# [epoch 1][310/761] loss: 2.0171 PSNR_train: 25.2350
# [epoch 1][311/761] loss: 2.0730 PSNR_train: 24.8522
# [epoch 1][312/761] loss: 2.1042 PSNR_train: 25.0124
# [epoch 1][313/761] loss: 2.0318 PSNR_train: 25.2740
# [epoch 1][314/761] loss: 2.0017 PSNR_train: 25.2372
# [epoch 1][315/761] loss: 2.1449 PSNR_train: 24.9420
# [epoch 1][316/761] loss: 2.2469 PSNR_train: 24.6704
# [epoch 1][317/761] loss: 2.2438 PSNR_train: 24.8008
# [epoch 1][318/761] loss: 2.2027 PSNR_train: 24.8892
# [epoch 1][319/761] loss: 1.9132 PSNR_train: 25.3339
# [epoch 1][320/761] loss: 2.1521 PSNR_train: 24.9851
# [epoch 1][321/761] loss: 1.9518 PSNR_train: 25.2110
# [epoch 1][322/761] loss: 2.0207 PSNR_train: 25.3355
# [epoch 1][323/761] loss: 1.9208 PSNR_train: 25.4221
# [epoch 1][324/761] loss: 2.3078 PSNR_train: 24.4873
# [epoch 1][325/761] loss: 1.9284 PSNR_train: 24.9462
# [epoch 1][326/761] loss: 2.0919 PSNR_train: 24.8115
# [epoch 1][327/761] loss: 2.0513 PSNR_train: 25.0112
# [epoch 1][328/761] loss: 2.1531 PSNR_train: 25.0200
# [epoch 1][329/761] loss: 2.0759 PSNR_train: 25.1619
# [epoch 1][330/761] loss: 2.1193 PSNR_train: 24.9966
# [epoch 1][331/761] loss: 2.1402 PSNR_train: 24.8304
# [epoch 1][332/761] loss: 2.1058 PSNR_train: 24.9227
# [epoch 1][333/761] loss: 2.0038 PSNR_train: 24.9299
# [epoch 1][334/761] loss: 2.1177 PSNR_train: 25.2245
# [epoch 1][335/761] loss: 2.0391 PSNR_train: 24.9915
# [epoch 1][336/761] loss: 2.1239 PSNR_train: 24.7257
# [epoch 1][337/761] loss: 2.0736 PSNR_train: 25.1349
# [epoch 1][338/761] loss: 1.8811 PSNR_train: 25.5339
# [epoch 1][339/761] loss: 2.1442 PSNR_train: 25.0429
# [epoch 1][340/761] loss: 1.9211 PSNR_train: 25.3685
# [epoch 1][341/761] loss: 2.0512 PSNR_train: 25.1092
# [epoch 1][342/761] loss: 2.1151 PSNR_train: 25.0213
# [epoch 1][343/761] loss: 2.1700 PSNR_train: 24.9120
# [epoch 1][344/761] loss: 2.0595 PSNR_train: 25.0409
# [epoch 1][345/761] loss: 2.2267 PSNR_train: 24.9227
# [epoch 1][346/761] loss: 1.9511 PSNR_train: 25.3119
# [epoch 1][347/761] loss: 2.1049 PSNR_train: 24.8621
# [epoch 1][348/761] loss: 2.0402 PSNR_train: 25.1808
# [epoch 1][349/761] loss: 2.1712 PSNR_train: 24.8235
# [epoch 1][350/761] loss: 1.9916 PSNR_train: 24.8646
# [epoch 1][351/761] loss: 2.0697 PSNR_train: 24.8147
# [epoch 1][352/761] loss: 2.2706 PSNR_train: 24.9181
# [epoch 1][353/761] loss: 1.9949 PSNR_train: 25.0863
# [epoch 1][354/761] loss: 2.1303 PSNR_train: 24.8970
# [epoch 1][355/761] loss: 2.1197 PSNR_train: 25.0771
# [epoch 1][356/761] loss: 1.9008 PSNR_train: 25.1995
# [epoch 1][357/761] loss: 1.9421 PSNR_train: 25.1063
# [epoch 1][358/761] loss: 1.9517 PSNR_train: 25.2796
# [epoch 1][359/761] loss: 2.0280 PSNR_train: 25.2191
# [epoch 1][360/761] loss: 1.9379 PSNR_train: 25.4016
# [epoch 1][361/761] loss: 2.1426 PSNR_train: 24.9666
# [epoch 1][362/761] loss: 1.9309 PSNR_train: 25.1991
# [epoch 1][363/761] loss: 2.0944 PSNR_train: 24.8892
# [epoch 1][364/761] loss: 1.9911 PSNR_train: 25.0277
# [epoch 1][365/761] loss: 2.0722 PSNR_train: 25.4258
# [epoch 1][366/761] loss: 2.1214 PSNR_train: 24.6530
# [epoch 1][367/761] loss: 1.7942 PSNR_train: 25.7321
# [epoch 1][368/761] loss: 1.9615 PSNR_train: 25.4090
# [epoch 1][369/761] loss: 1.8441 PSNR_train: 25.4447
# [epoch 1][370/761] loss: 2.1614 PSNR_train: 24.8906
# [epoch 1][371/761] loss: 2.0996 PSNR_train: 25.0068
# [epoch 1][372/761] loss: 1.9465 PSNR_train: 25.2612
# [epoch 1][373/761] loss: 2.1200 PSNR_train: 24.8732
# [epoch 1][374/761] loss: 1.8031 PSNR_train: 25.9229
# [epoch 1][375/761] loss: 1.9371 PSNR_train: 25.4254
# [epoch 1][376/761] loss: 2.0947 PSNR_train: 24.9294
# [epoch 1][377/761] loss: 1.9261 PSNR_train: 25.2631
# [epoch 1][378/761] loss: 2.1058 PSNR_train: 25.0194
# [epoch 1][379/761] loss: 1.8558 PSNR_train: 25.3054
# [epoch 1][380/761] loss: 1.9854 PSNR_train: 25.5332
# [epoch 1][381/761] loss: 1.9965 PSNR_train: 25.0623
# [epoch 1][382/761] loss: 2.0068 PSNR_train: 25.3117
# [epoch 1][383/761] loss: 1.9775 PSNR_train: 25.1262
# [epoch 1][384/761] loss: 2.0008 PSNR_train: 25.3697
# [epoch 1][385/761] loss: 2.1401 PSNR_train: 24.6194
# [epoch 1][386/761] loss: 1.8695 PSNR_train: 25.3863
# [epoch 1][387/761] loss: 1.9004 PSNR_train: 25.5616
# [epoch 1][388/761] loss: 2.1697 PSNR_train: 24.6500
# [epoch 1][389/761] loss: 1.9316 PSNR_train: 25.4795
# [epoch 1][390/761] loss: 1.9469 PSNR_train: 25.2837
# [epoch 1][391/761] loss: 1.9406 PSNR_train: 25.4629
# [epoch 1][392/761] loss: 1.9849 PSNR_train: 25.0597
# [epoch 1][393/761] loss: 2.0283 PSNR_train: 25.0879
# [epoch 1][394/761] loss: 2.1307 PSNR_train: 24.6142
# [epoch 1][395/761] loss: 2.0856 PSNR_train: 24.8385
# [epoch 1][396/761] loss: 2.1650 PSNR_train: 24.8346
# [epoch 1][397/761] loss: 2.0306 PSNR_train: 24.7611
# [epoch 1][398/761] loss: 1.9332 PSNR_train: 25.4293
# [epoch 1][399/761] loss: 2.1193 PSNR_train: 24.8204
# [epoch 1][400/761] loss: 2.1354 PSNR_train: 25.0887
# [epoch 1][401/761] loss: 2.2302 PSNR_train: 24.7264
# [epoch 1][402/761] loss: 2.1852 PSNR_train: 24.5726
# [epoch 1][403/761] loss: 1.8858 PSNR_train: 25.3549
# [epoch 1][404/761] loss: 2.2070 PSNR_train: 24.8943
# [epoch 1][405/761] loss: 1.9761 PSNR_train: 25.2814
# [epoch 1][406/761] loss: 2.0752 PSNR_train: 25.0048
# [epoch 1][407/761] loss: 1.9389 PSNR_train: 25.2534
# [epoch 1][408/761] loss: 2.0755 PSNR_train: 25.0854
# [epoch 1][409/761] loss: 1.7776 PSNR_train: 25.6747
# [epoch 1][410/761] loss: 1.9057 PSNR_train: 25.2189
# [epoch 1][411/761] loss: 2.0844 PSNR_train: 25.1585
# [epoch 1][412/761] loss: 1.9553 PSNR_train: 25.3409
# [epoch 1][413/761] loss: 1.9193 PSNR_train: 25.8666
# [epoch 1][414/761] loss: 1.9301 PSNR_train: 25.2820
# [epoch 1][415/761] loss: 1.9305 PSNR_train: 25.5112
# [epoch 1][416/761] loss: 2.0899 PSNR_train: 25.0191
# [epoch 1][417/761] loss: 1.8713 PSNR_train: 25.3906
# [epoch 1][418/761] loss: 1.9756 PSNR_train: 25.1907
# [epoch 1][419/761] loss: 2.0839 PSNR_train: 25.1210
# [epoch 1][420/761] loss: 1.8195 PSNR_train: 25.4278
# [epoch 1][421/761] loss: 2.3568 PSNR_train: 24.4094
# [epoch 1][422/761] loss: 2.0885 PSNR_train: 25.0505
# [epoch 1][423/761] loss: 1.8939 PSNR_train: 25.1792
# [epoch 1][424/761] loss: 2.0554 PSNR_train: 25.0758
# [epoch 1][425/761] loss: 1.8565 PSNR_train: 25.4610
# [epoch 1][426/761] loss: 1.9845 PSNR_train: 25.2295
# [epoch 1][427/761] loss: 1.9541 PSNR_train: 25.0656
# [epoch 1][428/761] loss: 1.9258 PSNR_train: 25.5475
# [epoch 1][429/761] loss: 1.9049 PSNR_train: 25.2922
# [epoch 1][430/761] loss: 2.0645 PSNR_train: 25.0466
# [epoch 1][431/761] loss: 2.0827 PSNR_train: 24.8894
# [epoch 1][432/761] loss: 2.2264 PSNR_train: 24.6728
# [epoch 1][433/761] loss: 1.9493 PSNR_train: 25.2650
# [epoch 1][434/761] loss: 2.1340 PSNR_train: 25.1192
# [epoch 1][435/761] loss: 1.8874 PSNR_train: 25.5329
# [epoch 1][436/761] loss: 1.9790 PSNR_train: 25.2852
# [epoch 1][437/761] loss: 2.1409 PSNR_train: 24.9853
# [epoch 1][438/761] loss: 2.0085 PSNR_train: 25.1712
# [epoch 1][439/761] loss: 2.0666 PSNR_train: 25.0473
# [epoch 1][440/761] loss: 1.9776 PSNR_train: 25.3670
# [epoch 1][441/761] loss: 2.0629 PSNR_train: 25.4102
# [epoch 1][442/761] loss: 2.0873 PSNR_train: 25.2371
# [epoch 1][443/761] loss: 1.9545 PSNR_train: 25.4577
# [epoch 1][444/761] loss: 2.0701 PSNR_train: 25.1643
# [epoch 1][445/761] loss: 1.9950 PSNR_train: 25.1371
# [epoch 1][446/761] loss: 1.9995 PSNR_train: 25.2273
# [epoch 1][447/761] loss: 2.1041 PSNR_train: 24.7479
# [epoch 1][448/761] loss: 2.1086 PSNR_train: 24.9049
# [epoch 1][449/761] loss: 1.9200 PSNR_train: 25.4260
# [epoch 1][450/761] loss: 2.0782 PSNR_train: 25.2489
# [epoch 1][451/761] loss: 1.8810 PSNR_train: 25.2435
# [epoch 1][452/761] loss: 2.0239 PSNR_train: 24.8546
# [epoch 1][453/761] loss: 2.0548 PSNR_train: 25.1077
# [epoch 1][454/761] loss: 2.2861 PSNR_train: 24.7162
# [epoch 1][455/761] loss: 1.9285 PSNR_train: 25.2439
# [epoch 1][456/761] loss: 2.0945 PSNR_train: 24.9287
# [epoch 1][457/761] loss: 1.8916 PSNR_train: 25.2857
# [epoch 1][458/761] loss: 2.0511 PSNR_train: 25.1495
# [epoch 1][459/761] loss: 1.8968 PSNR_train: 25.5015
# [epoch 1][460/761] loss: 1.9765 PSNR_train: 25.2961
# [epoch 1][461/761] loss: 1.9820 PSNR_train: 25.3839
# [epoch 1][462/761] loss: 2.0135 PSNR_train: 25.4448
# [epoch 1][463/761] loss: 1.8659 PSNR_train: 25.5170
# [epoch 1][464/761] loss: 1.9672 PSNR_train: 25.0143
# [epoch 1][465/761] loss: 1.7977 PSNR_train: 25.6478
# [epoch 1][466/761] loss: 1.9065 PSNR_train: 25.3773
# [epoch 1][467/761] loss: 2.0369 PSNR_train: 25.1983
# [epoch 1][468/761] loss: 2.0960 PSNR_train: 25.1120
# [epoch 1][469/761] loss: 1.9313 PSNR_train: 25.5168
# [epoch 1][470/761] loss: 1.8969 PSNR_train: 25.5251
# [epoch 1][471/761] loss: 2.1966 PSNR_train: 24.9559
# [epoch 1][472/761] loss: 1.9639 PSNR_train: 25.3748
# [epoch 1][473/761] loss: 2.1736 PSNR_train: 24.5934
# [epoch 1][474/761] loss: 1.8700 PSNR_train: 25.5048
# [epoch 1][475/761] loss: 2.0185 PSNR_train: 25.4384
# [epoch 1][476/761] loss: 1.9461 PSNR_train: 25.0667
# [epoch 1][477/761] loss: 1.8072 PSNR_train: 25.7052
# [epoch 1][478/761] loss: 1.9868 PSNR_train: 25.3137
# [epoch 1][479/761] loss: 2.0011 PSNR_train: 24.8687
# [epoch 1][480/761] loss: 1.8092 PSNR_train: 25.7824
# [epoch 1][481/761] loss: 1.9611 PSNR_train: 25.3639
# [epoch 1][482/761] loss: 2.1019 PSNR_train: 25.0913
# [epoch 1][483/761] loss: 2.0038 PSNR_train: 25.1750
# [epoch 1][484/761] loss: 1.8403 PSNR_train: 25.7692
# [epoch 1][485/761] loss: 1.8420 PSNR_train: 25.8304
# [epoch 1][486/761] loss: 1.9634 PSNR_train: 25.2620
# [epoch 1][487/761] loss: 1.9225 PSNR_train: 25.6773
# [epoch 1][488/761] loss: 2.0192 PSNR_train: 25.3072
# [epoch 1][489/761] loss: 2.1915 PSNR_train: 24.8532
# [epoch 1][490/761] loss: 2.1181 PSNR_train: 24.7541
# [epoch 1][491/761] loss: 1.9425 PSNR_train: 25.4445
# [epoch 1][492/761] loss: 1.9345 PSNR_train: 25.6155
# [epoch 1][493/761] loss: 1.9790 PSNR_train: 25.1571
# [epoch 1][494/761] loss: 1.8859 PSNR_train: 25.2304
# [epoch 1][495/761] loss: 2.0904 PSNR_train: 25.0321
# [epoch 1][496/761] loss: 2.0724 PSNR_train: 24.9767
# [epoch 1][497/761] loss: 2.0064 PSNR_train: 25.3061
# [epoch 1][498/761] loss: 2.0808 PSNR_train: 24.8903
# [epoch 1][499/761] loss: 2.1163 PSNR_train: 24.9515
# [epoch 1][500/761] loss: 2.0574 PSNR_train: 25.2835
# [epoch 1][501/761] loss: 1.8521 PSNR_train: 25.7082
# [epoch 1][502/761] loss: 1.8934 PSNR_train: 25.6348
# [epoch 1][503/761] loss: 2.0312 PSNR_train: 25.1509
# [epoch 1][504/761] loss: 1.9889 PSNR_train: 25.1159
# [epoch 1][505/761] loss: 1.8553 PSNR_train: 25.6399
# [epoch 1][506/761] loss: 1.8973 PSNR_train: 25.6280
# [epoch 1][507/761] loss: 1.9521 PSNR_train: 25.5369
# [epoch 1][508/761] loss: 1.9668 PSNR_train: 25.5622
# [epoch 1][509/761] loss: 2.1565 PSNR_train: 25.0507
# [epoch 1][510/761] loss: 2.0757 PSNR_train: 24.9162
# [epoch 1][511/761] loss: 2.1413 PSNR_train: 25.2874
# [epoch 1][512/761] loss: 2.0932 PSNR_train: 24.8334
# [epoch 1][513/761] loss: 1.9980 PSNR_train: 25.3922
# [epoch 1][514/761] loss: 1.8853 PSNR_train: 25.3824
# [epoch 1][515/761] loss: 2.0289 PSNR_train: 25.0020
# [epoch 1][516/761] loss: 2.0179 PSNR_train: 25.4425
# [epoch 1][517/761] loss: 2.0566 PSNR_train: 25.4188
# [epoch 1][518/761] loss: 1.9784 PSNR_train: 25.4146
# [epoch 1][519/761] loss: 1.8979 PSNR_train: 25.3317
# [epoch 1][520/761] loss: 2.1050 PSNR_train: 24.9110
# [epoch 1][521/761] loss: 2.0803 PSNR_train: 25.3647
# [epoch 1][522/761] loss: 1.8140 PSNR_train: 26.0567
# [epoch 1][523/761] loss: 1.9524 PSNR_train: 25.2034
# [epoch 1][524/761] loss: 1.8338 PSNR_train: 25.4309
# [epoch 1][525/761] loss: 2.0205 PSNR_train: 25.0402
# [epoch 1][526/761] loss: 1.8989 PSNR_train: 25.6756
# [epoch 1][527/761] loss: 2.0105 PSNR_train: 25.0793
# [epoch 1][528/761] loss: 1.7797 PSNR_train: 25.9536
# [epoch 1][529/761] loss: 1.8538 PSNR_train: 25.5059
# [epoch 1][530/761] loss: 1.9487 PSNR_train: 25.3904
# [epoch 1][531/761] loss: 2.0364 PSNR_train: 25.1556
# [epoch 1][532/761] loss: 2.1380 PSNR_train: 24.9296
# [epoch 1][533/761] loss: 1.9424 PSNR_train: 25.5402
# [epoch 1][534/761] loss: 1.7523 PSNR_train: 25.7866
# [epoch 1][535/761] loss: 1.9902 PSNR_train: 25.3876
# [epoch 1][536/761] loss: 2.0691 PSNR_train: 25.2221
# [epoch 1][537/761] loss: 2.1109 PSNR_train: 25.1401
# [epoch 1][538/761] loss: 1.9226 PSNR_train: 25.5073
# [epoch 1][539/761] loss: 1.9239 PSNR_train: 25.1427
# [epoch 1][540/761] loss: 1.8781 PSNR_train: 25.5568
# [epoch 1][541/761] loss: 1.9857 PSNR_train: 25.5974
# [epoch 1][542/761] loss: 2.0288 PSNR_train: 25.2865
# [epoch 1][543/761] loss: 1.9564 PSNR_train: 25.4307
# [epoch 1][544/761] loss: 2.0215 PSNR_train: 25.1279
# [epoch 1][545/761] loss: 2.0317 PSNR_train: 25.2405
# [epoch 1][546/761] loss: 2.0017 PSNR_train: 25.1854
# [epoch 1][547/761] loss: 1.9390 PSNR_train: 25.7078
# [epoch 1][548/761] loss: 2.2109 PSNR_train: 24.6636
# [epoch 1][549/761] loss: 1.8896 PSNR_train: 25.3889
# [epoch 1][550/761] loss: 1.7500 PSNR_train: 25.6657
# [epoch 1][551/761] loss: 2.0173 PSNR_train: 25.2142
# [epoch 1][552/761] loss: 2.0315 PSNR_train: 25.3684
# [epoch 1][553/761] loss: 1.9121 PSNR_train: 25.6781
# [epoch 1][554/761] loss: 1.8902 PSNR_train: 25.7352
# [epoch 1][555/761] loss: 2.0606 PSNR_train: 25.1125
# [epoch 1][556/761] loss: 1.8876 PSNR_train: 25.5806
# [epoch 1][557/761] loss: 2.0913 PSNR_train: 24.8411
# [epoch 1][558/761] loss: 1.8859 PSNR_train: 25.5534
# [epoch 1][559/761] loss: 1.9385 PSNR_train: 25.1067
# [epoch 1][560/761] loss: 2.1317 PSNR_train: 24.7096
# [epoch 1][561/761] loss: 2.0985 PSNR_train: 24.9058
# [epoch 1][562/761] loss: 2.1601 PSNR_train: 25.2184
# [epoch 1][563/761] loss: 2.0737 PSNR_train: 24.6972
# [epoch 1][564/761] loss: 1.9563 PSNR_train: 24.8525
# [epoch 1][565/761] loss: 2.0200 PSNR_train: 25.1719
# [epoch 1][566/761] loss: 1.9440 PSNR_train: 25.4982
# [epoch 1][567/761] loss: 1.9277 PSNR_train: 26.0992
# [epoch 1][568/761] loss: 2.1817 PSNR_train: 24.6851
# [epoch 1][569/761] loss: 1.8073 PSNR_train: 25.7351
# [epoch 1][570/761] loss: 2.0905 PSNR_train: 25.1316
# [epoch 1][571/761] loss: 1.9242 PSNR_train: 25.8316
# [epoch 1][572/761] loss: 2.0280 PSNR_train: 25.1534
# [epoch 1][573/761] loss: 2.0459 PSNR_train: 24.9019
# [epoch 1][574/761] loss: 2.0264 PSNR_train: 24.9395
# [epoch 1][575/761] loss: 1.9830 PSNR_train: 25.2737
# [epoch 1][576/761] loss: 2.0927 PSNR_train: 25.0862
# [epoch 1][577/761] loss: 2.2212 PSNR_train: 24.8236
# [epoch 1][578/761] loss: 1.8297 PSNR_train: 25.6489
# [epoch 1][579/761] loss: 1.9176 PSNR_train: 25.6238
# [epoch 1][580/761] loss: 1.8367 PSNR_train: 25.6268
# [epoch 1][581/761] loss: 2.0477 PSNR_train: 24.8206
# [epoch 1][582/761] loss: 1.9704 PSNR_train: 25.6043
# [epoch 1][583/761] loss: 1.8360 PSNR_train: 25.5141
# [epoch 1][584/761] loss: 2.0717 PSNR_train: 25.0266
# [epoch 1][585/761] loss: 1.9041 PSNR_train: 25.5867
# [epoch 1][586/761] loss: 1.8633 PSNR_train: 25.5625
# [epoch 1][587/761] loss: 1.9404 PSNR_train: 25.7338
# [epoch 1][588/761] loss: 2.1382 PSNR_train: 24.7095
# [epoch 1][589/761] loss: 2.0542 PSNR_train: 24.9581
# [epoch 1][590/761] loss: 1.9127 PSNR_train: 25.4363
# [epoch 1][591/761] loss: 1.8544 PSNR_train: 25.6962
# [epoch 1][592/761] loss: 1.9629 PSNR_train: 25.4592
# [epoch 1][593/761] loss: 1.9341 PSNR_train: 25.2958
# [epoch 1][594/761] loss: 2.1216 PSNR_train: 25.0309
# [epoch 1][595/761] loss: 2.0813 PSNR_train: 24.9390
# [epoch 1][596/761] loss: 1.9001 PSNR_train: 25.2310
# [epoch 1][597/761] loss: 1.9993 PSNR_train: 25.3577
# [epoch 1][598/761] loss: 2.0290 PSNR_train: 25.1413
# [epoch 1][599/761] loss: 1.9587 PSNR_train: 25.3199
# [epoch 1][600/761] loss: 1.9923 PSNR_train: 25.1037
# [epoch 1][601/761] loss: 1.9441 PSNR_train: 25.3332
# [epoch 1][602/761] loss: 2.0022 PSNR_train: 25.3397
# [epoch 1][603/761] loss: 2.2576 PSNR_train: 24.8625
# [epoch 1][604/761] loss: 1.6818 PSNR_train: 26.3150
# [epoch 1][605/761] loss: 1.9869 PSNR_train: 25.1432
# [epoch 1][606/761] loss: 1.8431 PSNR_train: 25.4222
# [epoch 1][607/761] loss: 2.0285 PSNR_train: 25.4510
# [epoch 1][608/761] loss: 2.1466 PSNR_train: 24.8590
# [epoch 1][609/761] loss: 2.0284 PSNR_train: 25.4643
# [epoch 1][610/761] loss: 1.8317 PSNR_train: 25.7051
# [epoch 1][611/761] loss: 1.9067 PSNR_train: 25.4111
# [epoch 1][612/761] loss: 1.7594 PSNR_train: 25.6389
# [epoch 1][613/761] loss: 2.0235 PSNR_train: 25.2302
# [epoch 1][614/761] loss: 2.1991 PSNR_train: 24.9573
# [epoch 1][615/761] loss: 1.8237 PSNR_train: 25.7392
# [epoch 1][616/761] loss: 2.0892 PSNR_train: 25.0505
# [epoch 1][617/761] loss: 1.9288 PSNR_train: 25.2905
# [epoch 1][618/761] loss: 2.0519 PSNR_train: 25.0691
# [epoch 1][619/761] loss: 1.9337 PSNR_train: 25.2755
# [epoch 1][620/761] loss: 1.8553 PSNR_train: 25.8299
# [epoch 1][621/761] loss: 2.0431 PSNR_train: 25.0684
# [epoch 1][622/761] loss: 1.9113 PSNR_train: 25.1259
# [epoch 1][623/761] loss: 1.8147 PSNR_train: 25.5328
# [epoch 1][624/761] loss: 1.9240 PSNR_train: 25.4154
# [epoch 1][625/761] loss: 2.0605 PSNR_train: 25.2344
# [epoch 1][626/761] loss: 2.0295 PSNR_train: 25.4038
# [epoch 1][627/761] loss: 2.1712 PSNR_train: 24.9599
# [epoch 1][628/761] loss: 2.1234 PSNR_train: 25.0922
# [epoch 1][629/761] loss: 2.0021 PSNR_train: 25.4619
# [epoch 1][630/761] loss: 2.0826 PSNR_train: 25.1168
# [epoch 1][631/761] loss: 1.9124 PSNR_train: 25.2858
# [epoch 1][632/761] loss: 1.9731 PSNR_train: 25.3841
# [epoch 1][633/761] loss: 2.0296 PSNR_train: 25.2729
# [epoch 1][634/761] loss: 2.0124 PSNR_train: 25.3710
# [epoch 1][635/761] loss: 1.8814 PSNR_train: 25.7622
# [epoch 1][636/761] loss: 2.0852 PSNR_train: 24.7473
# [epoch 1][637/761] loss: 1.8954 PSNR_train: 25.5878
# [epoch 1][638/761] loss: 1.7656 PSNR_train: 25.7391
# [epoch 1][639/761] loss: 1.9225 PSNR_train: 25.4455
# [epoch 1][640/761] loss: 1.9967 PSNR_train: 25.3817
# [epoch 1][641/761] loss: 1.9143 PSNR_train: 25.3978
# [epoch 1][642/761] loss: 1.9814 PSNR_train: 25.4203
# [epoch 1][643/761] loss: 1.9717 PSNR_train: 25.0308
# [epoch 1][644/761] loss: 2.0673 PSNR_train: 24.7994
# [epoch 1][645/761] loss: 1.9094 PSNR_train: 25.2398
# [epoch 1][646/761] loss: 1.9904 PSNR_train: 25.2896
# [epoch 1][647/761] loss: 2.0077 PSNR_train: 25.2993
# [epoch 1][648/761] loss: 1.9225 PSNR_train: 25.4168
# [epoch 1][649/761] loss: 1.8813 PSNR_train: 25.5541
# [epoch 1][650/761] loss: 1.9011 PSNR_train: 25.7913
# [epoch 1][651/761] loss: 2.0107 PSNR_train: 25.2274
# [epoch 1][652/761] loss: 1.8557 PSNR_train: 25.5824
# [epoch 1][653/761] loss: 2.0749 PSNR_train: 25.0659
# [epoch 1][654/761] loss: 1.8666 PSNR_train: 25.7651
# [epoch 1][655/761] loss: 1.8826 PSNR_train: 25.8936
# [epoch 1][656/761] loss: 1.9228 PSNR_train: 25.5686
# [epoch 1][657/761] loss: 2.0711 PSNR_train: 24.8203
# [epoch 1][658/761] loss: 2.1994 PSNR_train: 24.9600
# [epoch 1][659/761] loss: 1.9830 PSNR_train: 25.4748
# [epoch 1][660/761] loss: 1.8523 PSNR_train: 25.7430
# [epoch 1][661/761] loss: 1.9910 PSNR_train: 25.2852
# [epoch 1][662/761] loss: 1.8557 PSNR_train: 25.5211
# [epoch 1][663/761] loss: 1.8591 PSNR_train: 25.6041
# [epoch 1][664/761] loss: 1.9338 PSNR_train: 25.0890
# [epoch 1][665/761] loss: 2.0045 PSNR_train: 25.3480
# [epoch 1][666/761] loss: 1.9152 PSNR_train: 25.1269
# [epoch 1][667/761] loss: 1.7059 PSNR_train: 25.8632
# [epoch 1][668/761] loss: 1.9980 PSNR_train: 25.4479
# [epoch 1][669/761] loss: 1.9682 PSNR_train: 25.5425
# [epoch 1][670/761] loss: 1.9522 PSNR_train: 25.2334
# [epoch 1][671/761] loss: 1.9077 PSNR_train: 25.5630
# [epoch 1][672/761] loss: 2.1304 PSNR_train: 24.9331
# [epoch 1][673/761] loss: 2.0483 PSNR_train: 25.0434
# [epoch 1][674/761] loss: 2.0627 PSNR_train: 25.0528
# [epoch 1][675/761] loss: 2.1096 PSNR_train: 25.1063
# [epoch 1][676/761] loss: 2.0146 PSNR_train: 25.3307
# [epoch 1][677/761] loss: 1.7919 PSNR_train: 25.8705
# [epoch 1][678/761] loss: 1.9517 PSNR_train: 25.3810
# [epoch 1][679/761] loss: 1.9005 PSNR_train: 25.3853
# [epoch 1][680/761] loss: 1.9483 PSNR_train: 25.4180
# [epoch 1][681/761] loss: 1.8478 PSNR_train: 25.8625
# [epoch 1][682/761] loss: 1.7496 PSNR_train: 25.9740
# [epoch 1][683/761] loss: 2.1027 PSNR_train: 25.0505
# [epoch 1][684/761] loss: 1.9617 PSNR_train: 25.4580
# [epoch 1][685/761] loss: 1.8841 PSNR_train: 25.7368
# [epoch 1][686/761] loss: 2.0155 PSNR_train: 25.0699
# [epoch 1][687/761] loss: 2.1170 PSNR_train: 24.9611
# [epoch 1][688/761] loss: 2.0073 PSNR_train: 24.9840
# [epoch 1][689/761] loss: 1.9276 PSNR_train: 25.3618
# [epoch 1][690/761] loss: 2.0607 PSNR_train: 25.1195
# [epoch 1][691/761] loss: 1.8573 PSNR_train: 25.8139
# [epoch 1][692/761] loss: 1.8885 PSNR_train: 25.2932
# [epoch 1][693/761] loss: 1.9256 PSNR_train: 25.1807
# [epoch 1][694/761] loss: 1.8673 PSNR_train: 25.8513
# [epoch 1][695/761] loss: 2.0544 PSNR_train: 25.1594
# [epoch 1][696/761] loss: 1.9782 PSNR_train: 25.8399
# [epoch 1][697/761] loss: 1.8594 PSNR_train: 25.8854
# [epoch 1][698/761] loss: 1.9677 PSNR_train: 25.6022
# [epoch 1][699/761] loss: 2.0621 PSNR_train: 25.0592
# [epoch 1][700/761] loss: 2.0981 PSNR_train: 25.0386
# [epoch 1][701/761] loss: 2.0531 PSNR_train: 25.3016
# [epoch 1][702/761] loss: 2.0257 PSNR_train: 25.0364
# [epoch 1][703/761] loss: 2.0696 PSNR_train: 25.3996
# [epoch 1][704/761] loss: 1.8348 PSNR_train: 26.2992
# [epoch 1][705/761] loss: 2.1195 PSNR_train: 25.0825
# [epoch 1][706/761] loss: 1.9034 PSNR_train: 25.3254
# [epoch 1][707/761] loss: 1.8486 PSNR_train: 25.8740
# [epoch 1][708/761] loss: 1.9056 PSNR_train: 25.3587
# [epoch 1][709/761] loss: 1.8331 PSNR_train: 25.7118
# [epoch 1][710/761] loss: 2.1441 PSNR_train: 24.9329
# [epoch 1][711/761] loss: 2.2792 PSNR_train: 24.6580
# [epoch 1][712/761] loss: 1.7940 PSNR_train: 26.2506
# [epoch 1][713/761] loss: 2.0770 PSNR_train: 25.2305
# [epoch 1][714/761] loss: 1.9680 PSNR_train: 25.4440
# [epoch 1][715/761] loss: 1.8612 PSNR_train: 25.6725
# [epoch 1][716/761] loss: 2.0541 PSNR_train: 25.0918
# [epoch 1][717/761] loss: 2.0181 PSNR_train: 25.3959
# [epoch 1][718/761] loss: 1.9701 PSNR_train: 25.3583
# [epoch 1][719/761] loss: 2.1250 PSNR_train: 24.6550
# [epoch 1][720/761] loss: 1.7732 PSNR_train: 26.0274
# [epoch 1][721/761] loss: 2.1465 PSNR_train: 24.9853
# [epoch 1][722/761] loss: 1.9824 PSNR_train: 25.0979
# [epoch 1][723/761] loss: 1.9142 PSNR_train: 25.5519
# [epoch 1][724/761] loss: 2.0594 PSNR_train: 25.2968
# [epoch 1][725/761] loss: 2.0090 PSNR_train: 25.5109
# [epoch 1][726/761] loss: 2.1494 PSNR_train: 24.7997
# [epoch 1][727/761] loss: 2.0011 PSNR_train: 25.3355
# [epoch 1][728/761] loss: 1.9854 PSNR_train: 25.1895
# [epoch 1][729/761] loss: 1.8988 PSNR_train: 25.4804
# [epoch 1][730/761] loss: 1.8784 PSNR_train: 25.5180
# [epoch 1][731/761] loss: 2.0131 PSNR_train: 25.3173
# [epoch 1][732/761] loss: 1.9947 PSNR_train: 25.2276
# [epoch 1][733/761] loss: 1.9655 PSNR_train: 25.0742
# [epoch 1][734/761] loss: 1.9357 PSNR_train: 25.1319
# [epoch 1][735/761] loss: 1.8907 PSNR_train: 25.3925
# [epoch 1][736/761] loss: 1.8086 PSNR_train: 25.7446
# [epoch 1][737/761] loss: 2.0400 PSNR_train: 25.3649
# [epoch 1][738/761] loss: 1.9079 PSNR_train: 25.6141
# [epoch 1][739/761] loss: 1.9554 PSNR_train: 25.5003
# [epoch 1][740/761] loss: 2.0723 PSNR_train: 25.4226
# [epoch 1][741/761] loss: 1.9965 PSNR_train: 25.2248
# [epoch 1][742/761] loss: 1.9156 PSNR_train: 25.8125
# [epoch 1][743/761] loss: 1.7034 PSNR_train: 26.1922
# [epoch 1][744/761] loss: 1.9779 PSNR_train: 25.4548
# [epoch 1][745/761] loss: 1.8307 PSNR_train: 25.9402
# [epoch 1][746/761] loss: 2.0797 PSNR_train: 25.0014
# [epoch 1][747/761] loss: 2.0901 PSNR_train: 25.0039
# [epoch 1][748/761] loss: 1.8239 PSNR_train: 25.5107
# [epoch 1][749/761] loss: 2.1001 PSNR_train: 24.8770
# [epoch 1][750/761] loss: 1.8161 PSNR_train: 25.6698
# [epoch 1][751/761] loss: 2.0502 PSNR_train: 25.0132
# [epoch 1][752/761] loss: 2.1060 PSNR_train: 24.8835
# [epoch 1][753/761] loss: 2.0963 PSNR_train: 24.7821
# [epoch 1][754/761] loss: 1.8892 PSNR_train: 25.3875
# [epoch 1][755/761] loss: 2.0872 PSNR_train: 24.9650
# [epoch 1][756/761] loss: 1.7888 PSNR_train: 25.5683
# [epoch 1][757/761] loss: 2.0028 PSNR_train: 25.1172
# [epoch 1][758/761] loss: 2.0062 PSNR_train: 25.9099
# [epoch 1][759/761] loss: 1.9917 PSNR_train: 25.2825
# [epoch 1][760/761] loss: 1.8002 PSNR_train: 26.0149
# [epoch 1][761/761] loss: 2.1464 PSNR_train: 24.3855
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-82-ddae8511731a> in <module>
#      89                 noise[torch.rand(img_train.size()) > 0.9] = -1
#      90
# ---> 91             imgn_val = img_val + noise
#      92             img_val, imgn_val = Variable(img_val.cuda()), Variable(imgn_val.cuda())
#      93             out_val = torch.clamp(imgn_val-model(imgn_val), 0., 1.)
#
# RuntimeError: The size of tensor a (129) must match the size of tensor b (29) at non-singleton dimension 3

# %%
if opt.mode == 'S':
    noise = torch.FloatTensor(img_val.size()).normal_(mean=0, std=opt.noiseL)
elif opt.mode == 'B':
    noise = torch.zeros(img_val.size())
    stdN = np.random.uniform(noiseL_B[0], noiseL_B[1], size=noise.size()[0])
    for n in range(noise.size()[0]):
        sizeN = noise[0,:,:,:].size()
        noise[n,:,:,:] = torch.FloatTensor(sizeN).normal_(mean=0, std=stdN[n])
elif opt.mode == 'M': 
    noise = -img_val
    noise[torch.rand(img_val.size()) < 0.9] = 0 

imgn_val = img_val + noise
img_val, imgn_val = Variable(img_val.cuda()), Variable(imgn_val.cuda())
out_val = torch.clamp(imgn_val-model(imgn_val), 0., 1.)

# %%
plt.figure(figsize=[15, 5])
plt.subplot(311)
plt.imshow(img_val.detach().cpu().squeeze())

plt.subplot(312)
plt.imshow(imgn_val.detach().cpu().squeeze())

plt.subplot(313)
plt.imshow(out_val.detach().cpu().squeeze())

# %% [markdown]
# # test it on real data

# %%
data_path = os.path.join(dataset_train.root, 'testdata')
real_data = sio.loadmat(os.path.join(data_path, 'real_2pdata.mat'))
A2p = real_data['A']
A2p_corr = real_data['A_corr']
A2p_raw = real_data['A_raw']

# %%
def plot_2p_results(neuron_id, cmap='jet'): 
#     img_raw = A_corr[:, :, neuron_id]
    img_raw = A2p_raw[:,:,neuron_id]

    noise = img_raw.std()
    img_raw = img_raw[np.newaxis, np.newaxis, ...] / noise * opt.noiseL
    img_input = torch.Tensor(img_raw).cuda()
    img_output = model(img_input).detach().cpu().numpy()
    img_denoised = img_raw -img_output
    
    img_ai = A2p[:, :, neuron_id].squeeze()
    img_ai_raw = A2p_raw[:,:,neuron_id].squeeze()
    img_diff= img_ai_raw.squeeze() - img_ai
    
    img_diff = img_diff / noise * 0.1
    print(img_diff.shape)
    imgs = [img_raw.squeeze(), img_denoised.squeeze(), 
            img_output.squeeze(), img_ai/noise*0.1, img_diff]
    titles = ['unconstrained $a_i$', 'denoised $a_i$', 'residual', 'CNMF $a_i$', 'difference']
#     fig, axs = plt.subplots(len(imgs), 1, figsize=(18, 8))
    plt.figure(figsize=(12, 8))
    vlims = [[-0.1,1], [-0.1,1], [-0.2, 0.2], [-0.1,1], [-0.2, 0.2]]
    for i, img, title, vlim in zip(range(len(imgs)), imgs, titles, vlims): 
        plt.subplot(2,5, i+1)
        im = plt.imshow(img, cmap=cmap, clim=vlim)
        plt.colorbar()
#         divider = make_axes_locatable(ax)
#         cax = divider.append_axes("right", size="5%", pad=0.05)
        plt.title(title)
#         plt.colorbar(im, cax=cax)
    
#     plt.tight_layout()
    
    imgs = imgs[0:2]
    labels = ['raw image', 'denoised image']
#     plt.figure(figsize=(5, 8))
    plt.subplot(2,2,3)
    for i, img, label in zip(range(len(imgs)), imgs, labels): 
        __ = plt.hist(img.flatten(), bins=np.linspace(-0.1,1, 100), 
                     label=label)
        plt.yscale('log')
        plt.legend()

    plt.subplot(2,2, 4)
    plt.plot(img_raw.ravel(), img_denoised.ravel(), '.')
    plt.plot([-0.5, 2], [-0.5,2], c='r')
    plt.xlim([-0.1, 1])
    plt.ylim([-0.1, 1])
    plt.xlabel('raw pixel values')
    plt.ylabel('denoised pixel values')
#     plt.tight_layout()
    
    return img_raw, img_denoised

# %%
torch.save(model.state_dict(), os.path.join(opt.outf, 'net_{}_connector.pth'.format(opt.num_of_layers)))

# %%
dummy_input = torch.randn(1, 1, 60, 80, device='cuda')
file_onnx = os.path.join(opt.outf, 'net_{}_connector.onnx'.format(opt.num_of_layers))
torch.onnx.export(model, dummy_input, file_onnx)

# %%
example_id = 2
img_raw, img_denoised = plot_2p_results(20)
# Out:
# (60, 80)

# %%
plt.subplot(121)
plt.imshow((img_raw * (img_raw>0)).squeeze(), clim=[0,1])
plt.title('0-thresholding')
plt.subplot(122)
plt.imshow(img_denoised.squeeze(), clim=[0,1])
plt.title('NN-denoiser')
# Out:
# Text(0.5, 1.0, 'NN-denoiser')

# %% [markdown]
# # test baylor data

# %%
real_data = sio.loadmat(os.path.join(data_path, 'baylor_data.mat'))
A = real_data['A']
A_corr = real_data['A_corr']
A_em = real_data['A_em']

# %%
def plot_baylor_results(neuron_id, plane_id, cmap='jet'): 
    img_raw = A_corr[:, :, plane_id, neuron_id].reshape(1,1, 58, 129)
    noise = img_raw[img_raw!=0].std()
    img_raw = img_raw / img_raw.max() 
    img_input = torch.Tensor(img_raw).cuda()
    img_output = model(img_input).detach().cpu().numpy()
    img_denoised = img_raw -img_output
    
    img_ai = A[:, :, plane_id, neuron_id].squeeze()
    img_pi = A_em[:,:,plane_id, neuron_id].squeeze()
    
    imgs = [img_pi/img_pi.max(), img_ai/img_ai.max(), img_raw.squeeze(), img_denoised.squeeze(), img_output.squeeze()]
    titles = ['EM footprint', '2P footprint', 'corr. image', 'denoised corr. image', 'residual']
    fig, axs = plt.subplots(len(imgs), 1, figsize=(18, 8))
    for img, title, ax in zip(imgs, titles, axs): 
        im = ax.imshow(img, cmap=cmap, clim=[-0.1, 0.5])
        ax.set_ylabel(title)

# %%
plot_baylor_results(5,2)

# %%
#Here we visualize how well the model actually performs on the test data that we defined for it
for k in range(len(dataset_train)):
    img_val = torch.unsqueeze(dataset_val[k], 0)
    noise = torch.FloatTensor(img_val.size()).normal_(mean=0, std=opt.val_noiseL)
    imgn_val = img_val + noise
    img_val, imgn_val = Variable(img_val.cuda()), Variable(imgn_val.cuda())
    out_val = torch.clamp(imgn_val-model(imgn_val), 0., 1.)
    imgn_valCPU = imgn_val.detach().cpu().numpy()
    imgn_valCPU = imgn_valCPU.squeeze()
    out_valCPU = out_val.detach().cpu().numpy()
    out_valCPU = out_valCPU.squeeze()
    
    plt.figure()
    plt.imshow(imgn_valCPU)
    plt.figure()
    plt.imshow(out_valCPU)
    plt.show()
    input()
#     psnr_val += batch_PSNR(out_val, img_val, 1.)
# psnr_val /= len(dataset_val)
